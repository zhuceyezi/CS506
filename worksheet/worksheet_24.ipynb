# %% [markdown]
# # Worksheet 24
#
# Name:  Liang Han
# UID: U86104920
#
# ### Topics
#
# - Tuning Neural Networks
#
# ## Tuning Neural Networks
#
# Nothing to do in this worksheet except follow along in lecture / use this code to better understand Neural Networks.

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from tensorflow import keras, math, random, stack
from tensorflow.keras import layers, initializers
from tensorflow.keras.activations import relu

# Set random seed for reproducibility
np.random.seed(1)
random.set_seed(1)

# Data generation - don't modify
centers = [[0, 0]]
t, _ = datasets.make_blobs(n_samples=200, centers=centers, cluster_std=1,
                           random_state=1)

colors = np.array([x for x in 'bgrcmyk'])


# CURVE
def generate_curve_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x: m.cos(4 * x[0]) - x[1] < -.5 or m.cos(4 * x[0]) - x[1] > .5, t)))
    Y = np.array([1 if m.cos(4 * x[0]) - x[1] >= 0 else 0 for x in X])
    return X, Y


# The model - modify this
model = keras.models.Sequential()
model.add(layers.Dense(3, input_dim=2, activation="sigmoid"))
model.add(layers.Dense(1, activation="sigmoid"))
model.compile(loss="binary_crossentropy")

X, Y = generate_curve_data(t)

# plot the data
plt.scatter(X[:, 0], X[:, 1], color=colors[Y].tolist(), s=100, alpha=.9)
plt.show()

history = model.fit(X, Y, batch_size=50, epochs=200)

# Plot the decision boundary

# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
Z = model.predict(meshData)
Z = np.array([0 if x < .5 else 1 for x in Z])
Z = Z.reshape(xx.shape)
ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)
ax.axis('off')

# Plot also the training points
ax.scatter(X[:, 0], X[:, 1], color=colors[Y].tolist(), s=100, alpha=.9)
plt.title("Decision Boundary")
plt.show()
# Out:
# WARNING:tensorflow:From C:\Users\hln12\anaconda3\envs\py11\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# WARNING:tensorflow:From C:\Users\hln12\anaconda3\envs\py11\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# WARNING:tensorflow:From C:\Users\hln12\anaconda3\envs\py11\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# Epoch 1/200
# WARNING:tensorflow:From C:\Users\hln12\anaconda3\envs\py11\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# 3/3 [==============================] - 1s 11ms/step - loss: 0.7021
# Epoch 2/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6996
# Epoch 3/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6978
# Epoch 4/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6964
# Epoch 5/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6951
# Epoch 6/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6939
# Epoch 7/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6927
# Epoch 8/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6916
# Epoch 9/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6905
# Epoch 10/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6896
# Epoch 11/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6887
# Epoch 12/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6879
# Epoch 13/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6868
# Epoch 14/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6859
# Epoch 15/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6850
# Epoch 16/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6840
# Epoch 17/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6832
# Epoch 18/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6824
# Epoch 19/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6815
# Epoch 20/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6808
# Epoch 21/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6799
# Epoch 22/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6790
# Epoch 23/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6782
# Epoch 24/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6775
# Epoch 25/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6766
# Epoch 26/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6757
# Epoch 27/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6750
# Epoch 28/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6742
# Epoch 29/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6735
# Epoch 30/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6728
# Epoch 31/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6718
# Epoch 32/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6711
# Epoch 33/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6703
# Epoch 34/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6696
# Epoch 35/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6688
# Epoch 36/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6680
# Epoch 37/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6672
# Epoch 38/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6665
# Epoch 39/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6658
# Epoch 40/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6650
# Epoch 41/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6643
# Epoch 42/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6636
# Epoch 43/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6628
# Epoch 44/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6621
# Epoch 45/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6613
# Epoch 46/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6607
# Epoch 47/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6599
# Epoch 48/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6594
# Epoch 49/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6586
# Epoch 50/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6579
# Epoch 51/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6572
# Epoch 52/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6566
# Epoch 53/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6559
# Epoch 54/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6551
# Epoch 55/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6544
# Epoch 56/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6537
# Epoch 57/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6530
# Epoch 58/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6525
# Epoch 59/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6517
# Epoch 60/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6510
# Epoch 61/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6504
# Epoch 62/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6497
# Epoch 63/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6491
# Epoch 64/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6484
# Epoch 65/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6477
# Epoch 66/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6470
# Epoch 67/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6464
# Epoch 68/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6457
# Epoch 69/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6450
# Epoch 70/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6443
# Epoch 71/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6438
# Epoch 72/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6430
# Epoch 73/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6424
# Epoch 74/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6417
# Epoch 75/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6410
# Epoch 76/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6404
# Epoch 77/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6397
# Epoch 78/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6390
# Epoch 79/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6383
# Epoch 80/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6377
# Epoch 81/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6370
# Epoch 82/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6363
# Epoch 83/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6356
# Epoch 84/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6350
# Epoch 85/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6343
# Epoch 86/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6336
# Epoch 87/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6329
# Epoch 88/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6322
# Epoch 89/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6315
# Epoch 90/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6310
# Epoch 91/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6302
# Epoch 92/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6295
# Epoch 93/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6289
# Epoch 94/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6283
# Epoch 95/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6276
# Epoch 96/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6269
# Epoch 97/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6262
# Epoch 98/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6257
# Epoch 99/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6250
# Epoch 100/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6244
# Epoch 101/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6237
# Epoch 102/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6231
# Epoch 103/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6224
# Epoch 104/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6218
# Epoch 105/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6211
# Epoch 106/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6205
# Epoch 107/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6199
# Epoch 108/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6191
# Epoch 109/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6185
# Epoch 110/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6179
# Epoch 111/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6172
# Epoch 112/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6166
# Epoch 113/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6159
# Epoch 114/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6153
# Epoch 115/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6146
# Epoch 116/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6140
# Epoch 117/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6133
# Epoch 118/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6127
# Epoch 119/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6121
# Epoch 120/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6115
# Epoch 121/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6108
# Epoch 122/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6101
# Epoch 123/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6095
# Epoch 124/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6089
# Epoch 125/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6082
# Epoch 126/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6076
# Epoch 127/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6070
# Epoch 128/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6063
# Epoch 129/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6056
# Epoch 130/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6050
# Epoch 131/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6043
# Epoch 132/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6036
# Epoch 133/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6030
# Epoch 134/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6023
# Epoch 135/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6016
# Epoch 136/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6010
# Epoch 137/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6002
# Epoch 138/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5995
# Epoch 139/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5988
# Epoch 140/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5982
# Epoch 141/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5976
# Epoch 142/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5968
# Epoch 143/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5962
# Epoch 144/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5955
# Epoch 145/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5949
# Epoch 146/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5941
# Epoch 147/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5934
# Epoch 148/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5927
# Epoch 149/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5921
# Epoch 150/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5914
# Epoch 151/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5906
# Epoch 152/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5899
# Epoch 153/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5893
# Epoch 154/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5885
# Epoch 155/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5878
# Epoch 156/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5870
# Epoch 157/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5863
# Epoch 158/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5855
# Epoch 159/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5848
# Epoch 160/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5842
# Epoch 161/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5833
# Epoch 162/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5827
# Epoch 163/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5819
# Epoch 164/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5812
# Epoch 165/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5805
# Epoch 166/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5798
# Epoch 167/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5791
# Epoch 168/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5784
# Epoch 169/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5776
# Epoch 170/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5769
# Epoch 171/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5762
# Epoch 172/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5756
# Epoch 173/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5747
# Epoch 174/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5740
# Epoch 175/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5733
# Epoch 176/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5725
# Epoch 177/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5717
# Epoch 178/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5710
# Epoch 179/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5703
# Epoch 180/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5695
# Epoch 181/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5688
# Epoch 182/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5680
# Epoch 183/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5673
# Epoch 184/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5666
# Epoch 185/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5658
# Epoch 186/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5650
# Epoch 187/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5643
# Epoch 188/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5636
# Epoch 189/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5627
# Epoch 190/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5620
# Epoch 191/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5612
# Epoch 192/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5605
# Epoch 193/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5596
# Epoch 194/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5589
# Epoch 195/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5581
# Epoch 196/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5574
# Epoch 197/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5566
# Epoch 198/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5558
# Epoch 199/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5551
# Epoch 200/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5543
# 3602/3602 [==============================] - 8s 2ms/step
